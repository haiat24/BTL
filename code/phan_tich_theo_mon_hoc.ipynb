# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv(r'F:\python nhom4\data\BTL\data_sach\data2020.csv')
data2 = pd.read_csv(r'F:\python nhom4\data\BTL\data_sach\data2021.csv')
data3 = pd.read_csv(r'F:\python nhom4\data\BTL\data_sach\data2022.csv')
data4 = pd.read_csv(r'F:\python nhom4\data\BTL\data_sach\data2023.csv')
data5 = pd.read_csv(r'F:\python nhom4\data\BTL\data_sach\data2024.csv')
data_all = (
    pd.concat([data1, data2, data3, data4, data5], ignore_index= True)
)

# %% [markdown]
# Overview số lượng thí sinh

# %%
data_all['year'] = data_all['year'].astype(str)
data_all['year'].unique()
# Out:
# array(['2020', '2021', '2022', '2023', '2024'], dtype=object)

# %%
data_year = data_all
#Tinh toan so luong thi sinh moi nam
students_per_year = data_year['year'].value_counts().sort_index()

#Tinh ti le tang truong
growth_rate = students_per_year.pct_change() * 100

#Tao Dataframe de hien thi ket qua
students_growth = pd.DataFrame({
    'Số lượng thí sinh': students_per_year,
    'Tỉ lệ tăng trưởng năm': growth_rate # Corrected column name here
}).reset_index().rename(columns={'index': 'year'})

#Vẽ biểu đồ
fig, ax = plt.subplots(2, 1, figsize=(6, 6))

#Vẽ số lượng thí sinh
ax[0].bar(students_growth['year'], students_growth['Số lượng thí sinh'], color='blue')
ax[0].set_xlabel('year')
ax[0].set_ylabel('Số lượng thí sinh')
ax[0].set_title('Số lượng thí sinh qua các năm')
ax[0].grid(False)

#Vẽ tỉ lệ tăng trưởng
ax[1].bar(students_growth['year'], students_growth['Tỉ lệ tăng trưởng năm'], color='red') # Corrected column name here
ax[1].set_xlabel('year')
ax[1].set_ylabel('Tỷ lệ tăng trưởng (%)')
ax[1].set_title('Tỷ lệ tăng trưởng qua các năm')
ax[1].grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# Phân tích theo môn thi

# %% [markdown]
# Toán

# %%
data_all['toan'] = pd.to_numeric(data_all['toan'], errors='coerce')

df_mean = data_all.groupby('year')['toan'].mean()
print(df_mean)

plt.figure(figsize=(10, 6))
plt.plot(df_mean.index, df_mean.values, marker='o', color='b', label='Điểm trung bình môn Toán')
plt.title('Điểm trung bình môn Toán qua các năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# year
# 2020    6.662271
# 2021    6.636990
# 2022    6.466254
# 2023    6.250557
# 2024    6.447309
# Name: toan, dtype: float64

# %% [markdown]
# Ngữ văn

# %%
data_all['ngu_van'] = pd.to_numeric(data_all['ngu_van'], errors='coerce')

df_mean = data_all.groupby('year')['ngu_van'].mean()
print(df_mean)

plt.figure(figsize=(10, 6))
plt.plot(df_mean.index, df_mean.values, marker='o', color='b', label='Điểm trung bình môn Ngũ Văn')
plt.title('Điểm trung bình môn Ngũ Văn qua các năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# year
# 2020    6.601825
# 2021    6.471883
# 2022    6.507746
# 2023    6.858194
# 2024    7.231146
# Name: ngu_van, dtype: float64

# %% [markdown]
# Vật lý

# %%
data_all['vat_ly'] = pd.to_numeric(data_all['vat_ly'], errors='coerce')

df_mean = data_all.groupby('year')['vat_ly'].mean()
print(df_mean)

plt.figure(figsize=(10, 6))
plt.plot(df_mean.index, df_mean.values, marker='o', color='b', label='Điểm trung bình môn Vật Lý')
plt.title('Điểm trung bình môn Vật Lý qua các năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# year
# 2020    6.718001
# 2021    6.565690
# 2022    6.723779
# 2023    6.573900
# 2024    6.666866
# Name: vat_ly, dtype: float64

# %% [markdown]
# Hóa học

# %%
data_all['hoa_hoc'] = pd.to_numeric(data_all['hoa_hoc'], errors='coerce')

df_mean = data_all.groupby('year')['hoa_hoc'].mean()
print(df_mean)

plt.figure(figsize=(10, 6))
plt.plot(df_mean.index, df_mean.values, marker='o', color='b', label='Điểm trung bình môn Hóa Học')
plt.title('Điểm trung bình môn Hóa Học qua các năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# year
# 2020    6.705225
# 2021    6.623471
# 2022    6.703898
# 2023    6.744646
# 2024    6.680830
# Name: hoa_hoc, dtype: float64

# %% [markdown]
# Sinh học

# %%
data_all['sinh_hoc'] = pd.to_numeric(data_all['sinh_hoc'], errors='coerce')

df_mean = data_all.groupby('year')['sinh_hoc'].mean()
print(df_mean)

plt.figure(figsize=(10, 6))
plt.plot(df_mean.index, df_mean.values, marker='o', color='b', label='Điểm trung bình môn Sinh Học')
plt.title('Điểm trung bình môn Sinh Học qua các năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# year
# 2020    5.588041
# 2021    5.517103
# 2022    5.019109
# 2023    6.394933
# 2024    6.284079
# Name: sinh_hoc, dtype: float64

# %% [markdown]
# Lịch sử

# %%
data_all['lich_su'] = pd.to_numeric(data_all['lich_su'], errors='coerce')

df_mean = data_all.groupby('year')['lich_su'].mean()
print(df_mean)

plt.figure(figsize=(10, 6))
plt.plot(df_mean.index, df_mean.values, marker='o', color='b', label='Điểm trung bình môn Lịch Sử')
plt.title('Điểm trung bình môn Lịch Sử qua các năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# year
# 2020    5.181097
# 2021    4.982117
# 2022    6.343930
# 2023    6.025629
# 2024    6.570343
# Name: lich_su, dtype: float64

# %% [markdown]
# Địa lý

# %%
data_all['dia_ly'] = pd.to_numeric(data_all['dia_ly'], errors='coerce')

df_mean = data_all.groupby('year')['dia_ly'].mean()
print(df_mean)

plt.figure(figsize=(10, 6))
plt.plot(df_mean.index, df_mean.values, marker='o', color='b', label='Điểm trung bình môn Địa Lý')
plt.title('Điểm trung bình môn Địa Lý qua các năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# year
# 2020    6.773215
# 2021    6.964827
# 2022    6.677929
# 2023    6.147523
# 2024    7.193541
# Name: dia_ly, dtype: float64

# %% [markdown]
# GDCD

# %%
data_all['gdcd'] = pd.to_numeric(data_all['gdcd'], errors='coerce')

df_mean = data_all.groupby('year')['gdcd'].mean()
print(df_mean)

plt.figure(figsize=(10, 6))
plt.plot(df_mean.index, df_mean.values, marker='o', color='b', label='Điểm trung bình môn GDCD')
plt.title('Điểm trung bình môn GDCD qua các năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# year
# 2020    8.125164
# 2021    8.385959
# 2022    8.033266
# 2023    8.285805
# 2024    8.156503
# Name: gdcd, dtype: float64

# %% [markdown]
# Ngoại ngữ

# %%
data_all['ngoai_ngu'] = pd.to_numeric(data_all['ngoai_ngu'], errors='coerce')

df_mean = data_all.groupby('year')['ngoai_ngu'].mean()
print(df_mean)

plt.figure(figsize=(10, 6))
plt.plot(df_mean.index, df_mean.values, marker='o', color='b', label='Điểm trung bình môn Ngoại Ngữ')
plt.title('Điểm trung bình môn Ngoại Ngữ qua các năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# year
# 2020    4.568337
# 2021    5.880415
# 2022    5.157686
# 2023    5.462410
# 2024    5.521938
# Name: ngoai_ngu, dtype: float64

# %% [markdown]
# Biểu đồ điểm trung bình

# %%
df = pd.DataFrame(data_all)
# Đảm bảo tất cả các cột điểm là dạng số
df[['toan', 'ngu_van', 'vat_ly', 'gdcd', 'ngoai_ngu', 'hoa_hoc', 'sinh_hoc', 'lich_su', 'dia_ly']] = df[['toan', 'ngu_van', 'vat_ly', 'gdcd', 'ngoai_ngu', 'hoa_hoc', 'sinh_hoc', 'lich_su', 'dia_ly']].apply(pd.to_numeric, errors='coerce')

# Tính điểm trung bình theo từng năm
df_mean = df.groupby('year')[['toan', 'ngu_van', 'vat_ly', 'gdcd', 'ngoai_ngu', 'hoa_hoc', 'sinh_hoc', 'lich_su', 'dia_ly']].mean()

# Vẽ biểu đồ
plt.figure(figsize=(10, 6))
for column in df_mean.columns:
    plt.plot(df_mean.index, df_mean[column], marker='o', label=column)

plt.title('Điểm trung bình các môn qua từng năm')
plt.xlabel('Năm')
plt.ylabel('Điểm trung bình')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Biểu đồ điểm các môn theo từng năm

# %%
# Thiết lập dữ liệu cho từng năm
data_2020 = data_all[data_all['year'] == "2020"]
data_2021 = data_all[data_all['year'] == "2021"]
data_2022 = data_all[data_all['year'] == "2022"]
data_2023 = data_all[data_all['year'] == "2023"]
data_2024 = data_all[data_all['year'] == "2024"]

# Danh sách môn học và màu sắc
subjects = ['toan', 'ngu_van', 'vat_ly', 'hoa_hoc', 'sinh_hoc', 'lich_su', 'dia_ly', 'gdcd', 'ngoai_ngu']
colors = ['#FF6347', '#4682B4', '#32CD32', '#FFD700', '#8A2BE2', '#DC143C', '#FF4500', '#2E8B57', '#D2691E']
years = [2020, 2021, 2022, 2023, 2024]

# Tạo lưới 5 hàng x 9 cột
fig, axes = plt.subplots(5, 9, figsize=(18, 12), sharey=True)

# Lặp qua từng năm và từng môn để tạo biểu đồ
for j, year in enumerate(years):
    data_year = data_all[data_all['year'] == str(year)]
    for i, subject in enumerate(subjects):
        ax = axes[j, i]  # Truy cập vào trục con tại vị trí [j, i]
        color = colors[i]

        # Vẽ biểu đồ histogram cho từng môn học của từng năm
        ax.hist(data_year[subject].dropna(), bins=20, alpha=0.7, color=color)
        ax.set_title(f'{subject} - {year}', fontsize=10, fontweight='bold')
        ax.set_ylabel('Số lượng', fontsize=8)
        ax.grid(True, linestyle='--', alpha=0.5)
        ax.tick_params(axis='both', labelsize=8)

# Điều chỉnh khoảng cách giữa các biểu đồ
plt.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# Xem điểm từng môn nằm trong top nào

# %%
data_all['year'] = pd.to_numeric(data_all['year'])

score = list(range(0, 11, 1))

fig, axes = plt.subplots(5, 1, figsize = (8, 8), sharex=True)

for i, year in enumerate([2020, 2021, 2022, 2023, 2024]):
    sns.histplot(data_all[data_all['year'] == year]['toan'].dropna(), bins=20, kde=False, ax=axes[i])
    axes[i].set_title(f'{year}')
    axes[i].set_xlabel('diem toan')
    axes[i].set_ylabel('so luong')

    year_data = data_all[data_all['year']==year]['toan'].dropna()
    mean = year_data.mean()
    median = year_data.median()
    std_dev = year_data.std()
    p70 = year_data.quantile(0.70)
    p80 = year_data.quantile(0.80)
    p90 = year_data.quantile(0.90)
    p93 = year_data.quantile(0.93)
    p95 = year_data.quantile(0.95)
    p97 = year_data.quantile(0.97)
    p99 = year_data.quantile(0.99)
    textstr = (f'Mean: {mean:.2f}\nMedian: {median:.2f}\nSTD: {std_dev:.2f}\n'
               f'P70 : {p70:.2f}\nP80: {p80:.2f}\nP90: {p90:.2f}\n'
               f'P93 : {p93:.2f}\nP95: {p95:.2f}\nP97: {p97:.2f}\nP99: {p99:.2f}')
    props = dict(boxstyle = 'round', facecolor='wheat', alpha = 0.5)
    axes[i].text(1.05, 0.5, textstr, transform=axes[i].transAxes, fontsize=8,
                 verticalalignment='center', horizontalalignment='left', bbox=props)
plt.xticks(score)
plt.tight_layout()
plt.show()

# %%
score = list(range(0, 11, 1))

fig, axes = plt.subplots(5, 1, figsize = (8, 8), sharex=True)

for i, year in enumerate([2020, 2021, 2022, 2023, 2024]):
    sns.histplot(data_all[data_all['year'] == year]['ngu_van'].dropna(), bins=20, kde=False, ax=axes[i])
    axes[i].set_title(f'{year}')
    axes[i].set_xlabel('diem ngu van')
    axes[i].set_ylabel('so luong')

    year_data = data_all[data_all['year']==year]['ngu_van'].dropna()
    mean = year_data.mean()
    median = year_data.median()
    std_dev = year_data.std()
    p70 = year_data.quantile(0.70)
    p80 = year_data.quantile(0.80)
    p90 = year_data.quantile(0.90)
    p93 = year_data.quantile(0.93)
    p95 = year_data.quantile(0.95)
    p97 = year_data.quantile(0.97)
    p99 = year_data.quantile(0.99)
    textstr = (f'Mean: {mean:.2f}\nMedian: {median:.2f}\nSTD: {std_dev:.2f}\n'
               f'P70 : {p70:.2f}\nP80: {p80:.2f}\nP90: {p90:.2f}\n'
               f'P93 : {p93:.2f}\nP95: {p95:.2f}\nP97: {p97:.2f}\nP99: {p99:.2f}')
    props = dict(boxstyle = 'round', facecolor='wheat', alpha = 0.5)
    axes[i].text(1.05, 0.5, textstr, transform=axes[i].transAxes, fontsize=8,
                 verticalalignment='center', horizontalalignment='left', bbox=props)
plt.xticks(score)
plt.tight_layout()
plt.show()

# %%
score = list(range(0, 11, 1))

fig, axes = plt.subplots(5, 1, figsize = (8, 8), sharex=True)

for i, year in enumerate([2020, 2021, 2022, 2023, 2024]):
    sns.histplot(data_all[data_all['year'] == year]['ngoai_ngu'].dropna(), bins=20, kde=False, ax=axes[i])
    axes[i].set_title(f'{year}')
    axes[i].set_xlabel('diem ngoai ngu')
    axes[i].set_ylabel('so luong')

    year_data = data_all[data_all['year']==year]['ngoai_ngu'].dropna()
    mean = year_data.mean()
    median = year_data.median()
    std_dev = year_data.std()
    p70 = year_data.quantile(0.70)
    p80 = year_data.quantile(0.80)
    p90 = year_data.quantile(0.90)
    p93 = year_data.quantile(0.93)
    p95 = year_data.quantile(0.95)
    p97 = year_data.quantile(0.97)
    p99 = year_data.quantile(0.99)
    textstr = (f'Mean: {mean:.2f}\nMedian: {median:.2f}\nSTD: {std_dev:.2f}\n'
               f'P70 : {p70:.2f}\nP80: {p80:.2f}\nP90: {p90:.2f}\n'
               f'P93 : {p93:.2f}\nP95: {p95:.2f}\nP97: {p97:.2f}\nP99: {p99:.2f}')
    props = dict(boxstyle = 'round', facecolor='wheat', alpha = 0.5)
    axes[i].text(1.05, 0.5, textstr, transform=axes[i].transAxes, fontsize=8,
                 verticalalignment='center', horizontalalignment='left', bbox=props)
plt.xticks(score)
plt.tight_layout()
plt.show()

# %%
score = list(range(0, 11, 1))

fig, axes = plt.subplots(5, 1, figsize = (8, 8), sharex=True)

for i, year in enumerate([2020, 2021, 2022, 2023, 2024]):
    sns.histplot(data_all[data_all['year'] == year]['vat_ly'].dropna(), bins=20, kde=False, ax=axes[i])
    axes[i].set_title(f'{year}')
    axes[i].set_xlabel('diem vat ly')
    axes[i].set_ylabel('so luong')

    year_data = data_all[data_all['year']==year]['vat_ly'].dropna()
    mean = year_data.mean()
    median = year_data.median()
    std_dev = year_data.std()
    p70 = year_data.quantile(0.70)
    p80 = year_data.quantile(0.80)
    p90 = year_data.quantile(0.90)
    p93 = year_data.quantile(0.93)
    p95 = year_data.quantile(0.95)
    p97 = year_data.quantile(0.97)
    p99 = year_data.quantile(0.99)
    textstr = (f'Mean: {mean:.2f}\nMedian: {median:.2f}\nSTD: {std_dev:.2f}\n'
               f'P70 : {p70:.2f}\nP80: {p80:.2f}\nP90: {p90:.2f}\n'
               f'P93 : {p93:.2f}\nP95: {p95:.2f}\nP97: {p97:.2f}\nP99: {p99:.2f}')
    props = dict(boxstyle = 'round', facecolor='wheat', alpha = 0.5)
    axes[i].text(1.05, 0.5, textstr, transform=axes[i].transAxes, fontsize=8,
                 verticalalignment='center', horizontalalignment='left', bbox=props)
plt.xticks(score)
plt.tight_layout()
plt.show()

# %%
score = list(range(0, 11, 1))

fig, axes = plt.subplots(5, 1, figsize = (8, 8), sharex=True)

for i, year in enumerate([2020, 2021, 2022, 2023, 2024]):
    sns.histplot(data_all[data_all['year'] == year]['hoa_hoc'].dropna(), bins=20, kde=False, ax=axes[i])
    axes[i].set_title(f'{year}')
    axes[i].set_xlabel('diem hoa hoc')
    axes[i].set_ylabel('so luong')

    year_data = data_all[data_all['year']==year]['hoa_hoc'].dropna()
    mean = year_data.mean()
    median = year_data.median()
    std_dev = year_data.std()
    p70 = year_data.quantile(0.70)
    p80 = year_data.quantile(0.80)
    p90 = year_data.quantile(0.90)
    p93 = year_data.quantile(0.93)
    p95 = year_data.quantile(0.95)
    p97 = year_data.quantile(0.97)
    p99 = year_data.quantile(0.99)
    textstr = (f'Mean: {mean:.2f}\nMedian: {median:.2f}\nSTD: {std_dev:.2f}\n'
               f'P70 : {p70:.2f}\nP80: {p80:.2f}\nP90: {p90:.2f}\n'
               f'P93 : {p93:.2f}\nP95: {p95:.2f}\nP97: {p97:.2f}\nP99: {p99:.2f}')
    props = dict(boxstyle = 'round', facecolor='wheat', alpha = 0.5)
    axes[i].text(1.05, 0.5, textstr, transform=axes[i].transAxes, fontsize=8,
                 verticalalignment='center', horizontalalignment='left', bbox=props)
plt.xticks(score)
plt.tight_layout()
plt.show()

# %%
score = list(range(0, 11, 1))

fig, axes = plt.subplots(5, 1, figsize = (8, 8), sharex=True)

for i, year in enumerate([2020, 2021, 2022, 2023, 2024]):
    sns.histplot(data_all[data_all['year'] == year]['sinh_hoc'].dropna(), bins=20, kde=False, ax=axes[i])
    axes[i].set_title(f'{year}')
    axes[i].set_xlabel('diem sinh hoc')
    axes[i].set_ylabel('so luong')

    year_data = data_all[data_all['year']==year]['sinh_hoc'].dropna()
    mean = year_data.mean()
    median = year_data.median()
    std_dev = year_data.std()
    p70 = year_data.quantile(0.70)
    p80 = year_data.quantile(0.80)
    p90 = year_data.quantile(0.90)
    p93 = year_data.quantile(0.93)
    p95 = year_data.quantile(0.95)
    p97 = year_data.quantile(0.97)
    p99 = year_data.quantile(0.99)
    textstr = (f'Mean: {mean:.2f}\nMedian: {median:.2f}\nSTD: {std_dev:.2f}\n'
               f'P70 : {p70:.2f}\nP80: {p80:.2f}\nP90: {p90:.2f}\n'
               f'P93 : {p93:.2f}\nP95: {p95:.2f}\nP97: {p97:.2f}\nP99: {p99:.2f}')
    props = dict(boxstyle = 'round', facecolor='wheat', alpha = 0.5)
    axes[i].text(1.05, 0.5, textstr, transform=axes[i].transAxes, fontsize=8,
                 verticalalignment='center', horizontalalignment='left', bbox=props)
plt.xticks(score)
plt.tight_layout()
plt.show()

# %%
score = list(range(0, 11, 1))

fig, axes = plt.subplots(5, 1, figsize = (8, 8), sharex=True)

for i, year in enumerate([2020, 2021, 2022, 2023, 2024]):
    sns.histplot(data_all[data_all['year'] == year]['lich_su'].dropna(), bins=20, kde=False, ax=axes[i])
    axes[i].set_title(f'{year}')
    axes[i].set_xlabel('diem lich_su')
    axes[i].set_ylabel('so luong')

    year_data = data_all[data_all['year']==year]['lich_su'].dropna()
    mean = year_data.mean()
    median = year_data.median()
    std_dev = year_data.std()
    p70 = year_data.quantile(0.70)
    p80 = year_data.quantile(0.80)
    p90 = year_data.quantile(0.90)
    p93 = year_data.quantile(0.93)
    p95 = year_data.quantile(0.95)
    p97 = year_data.quantile(0.97)
    p99 = year_data.quantile(0.99)
    textstr = (f'Mean: {mean:.2f}\nMedian: {median:.2f}\nSTD: {std_dev:.2f}\n'
               f'P70 : {p70:.2f}\nP80: {p80:.2f}\nP90: {p90:.2f}\n'
               f'P93 : {p93:.2f}\nP95: {p95:.2f}\nP97: {p97:.2f}\nP99: {p99:.2f}')
    props = dict(boxstyle = 'round', facecolor='wheat', alpha = 0.5)
    axes[i].text(1.05, 0.5, textstr, transform=axes[i].transAxes, fontsize=8,
                 verticalalignment='center', horizontalalignment='left', bbox=props)
plt.xticks(score)
plt.tight_layout()
plt.show()

# %%
score = list(range(0, 11, 1))

fig, axes = plt.subplots(5, 1, figsize = (8, 8), sharex=True)

for i, year in enumerate([2020, 2021, 2022, 2023, 2024]):
    sns.histplot(data_all[data_all['year'] == year]['dia_ly'].dropna(), bins=20, kde=False, ax=axes[i])
    axes[i].set_title(f'{year}')
    axes[i].set_xlabel('diem dia ly')
    axes[i].set_ylabel('so luong')

    year_data = data_all[data_all['year']==year]['dia_ly'].dropna()
    mean = year_data.mean()
    median = year_data.median()
    std_dev = year_data.std()
    p70 = year_data.quantile(0.70)
    p80 = year_data.quantile(0.80)
    p90 = year_data.quantile(0.90)
    p93 = year_data.quantile(0.93)
    p95 = year_data.quantile(0.95)
    p97 = year_data.quantile(0.97)
    p99 = year_data.quantile(0.99)
    textstr = (f'Mean: {mean:.2f}\nMedian: {median:.2f}\nSTD: {std_dev:.2f}\n'
               f'P70 : {p70:.2f}\nP80: {p80:.2f}\nP90: {p90:.2f}\n'
               f'P93 : {p93:.2f}\nP95: {p95:.2f}\nP97: {p97:.2f}\nP99: {p99:.2f}')
    props = dict(boxstyle = 'round', facecolor='wheat', alpha = 0.5)
    axes[i].text(1.05, 0.5, textstr, transform=axes[i].transAxes, fontsize=8,
                 verticalalignment='center', horizontalalignment='left', bbox=props)
plt.xticks(score)
plt.tight_layout()
plt.show()

# %%
score = list(range(0, 11, 1))

fig, axes = plt.subplots(5, 1, figsize = (8, 8), sharex=True)

for i, year in enumerate([2020, 2021, 2022, 2023, 2024]):
    sns.histplot(data_all[data_all['year'] == year]['gdcd'].dropna(), bins=20, kde=False, ax=axes[i])
    axes[i].set_title(f'{year}')
    axes[i].set_xlabel('diem GDCD')
    axes[i].set_ylabel('so luong')

    year_data = data_all[data_all['year']==year]['gdcd'].dropna()
    mean = year_data.mean()
    median = year_data.median()
    std_dev = year_data.std()
    p70 = year_data.quantile(0.70)
    p80 = year_data.quantile(0.80)
    p90 = year_data.quantile(0.90)
    p93 = year_data.quantile(0.93)
    p95 = year_data.quantile(0.95)
    p97 = year_data.quantile(0.97)
    p99 = year_data.quantile(0.99)
    textstr = (f'Mean: {mean:.2f}\nMedian: {median:.2f}\nSTD: {std_dev:.2f}\n'
               f'P70 : {p70:.2f}\nP80: {p80:.2f}\nP90: {p90:.2f}\n'
               f'P93 : {p93:.2f}\nP95: {p95:.2f}\nP97: {p97:.2f}\nP99: {p99:.2f}')
    props = dict(boxstyle = 'round', facecolor='wheat', alpha = 0.5)
    axes[i].text(1.05, 0.5, textstr, transform=axes[i].transAxes, fontsize=8,
                 verticalalignment='center', horizontalalignment='left', bbox=props)
plt.xticks(score)
plt.tight_layout()
plt.show()
